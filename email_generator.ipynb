# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.9/617.9 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 67.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 81.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# ...

# %%
# !pip install langchain-groq
from langchain_groq import ChatGroq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 3.3 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0,
    groq_api_key='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',
    model_name="llama-3.1-70b-versatile"
)
response = llm.invoke("The seccond person to land on moon was ...")
print(response.content)
# Out:
# The second person to land on the moon was Edwin "Buzz" Aldrin. He stepped onto the lunar surface on July 20, 1969, during the Apollo 11 mission, following Neil Armstrong, who was the first person to set foot on the moon.

# %%
from langchain_community.document_loaders import WebBaseLoader
#nike job posting
#loader = WebBaseLoader("https://www.google.com/about/careers/applications/jobs/results/138914497711481542-ux-interaction-designer-university-graduate-2025-start?category=DATA_CENTER_OPERATIONS&category=DEVELOPER_RELATIONS&category=HARDWARE_ENGINEERING&category=INFORMATION_TECHNOLOGY&category=MANUFACTURING_SUPPLY_CHAIN&category=NETWORK_ENGINEERING&category=PRODUCT_MANAGEMENT&category=PROGRAM_MANAGEMENT&category=SOFTWARE_ENGINEERING&category=TECHNICAL_INFRASTRUCTURE_ENGINEERING&category=TECHNICAL_SOLUTIONS&category=TECHNICAL_WRITING&category=USER_EXPERIENCE&employment_type=FULL_TIME&employment_type=PART_TIME&employment_type=TEMPORARY&jex=ENTRY_LEVEL")
loader = WebBaseLoader("https://jobs.nike.com/job/R-45734?from=job%20search%20funnel")
#puma job posting
#loader = WebBaseLoader("https://about.puma.com/en/jobs/senior-category-manager-ecommerce-europe-r33565")
#loader = WebBaseLoader("https://www.naukri.com/job-listings-web-developer-kimberlite-softwares-private-limited-bengaluru-1-to-3-years-221124506454?src=jobsearchDesk&sid=17323669734688219&xp=4&px=1")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# Apply for Software Engineer II, ITC
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract and combine the job postings and return them in JSON format containing the
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):
        """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke(input={'page_data':page_data})
print(res.content)
# Out:
# ```json
# {
#   "role": "Software Engineer II, ITC",
#   "experience": "3-5 years",
#   "skills": [
#     "Java",
#     "Spring Boot",
#     "ReactJS",
#     "HTML5",
#     "CSS3",
#     "JavaScript",
#     "Typescript",
#     "Micro service architecture",
#     "Domain driven design",
#     "RESTful Services",
#     "UI/UX principles",
#     "Continuous integration",
#     "Unit testing",
#     "Static analysis",
#     "Automated integration tests",
#     "Scrum and agile principles",
#     "AWS Services",
#     "GCE",
#     "Rackspace",
#     "Azure",
#     "NoSQL data stores (Cassandra, DynamoDB, MongoDB)",
#     "Relational data stores (MySQL, Oracle)",
#     "Splunk",
#     "SignalFx",
#     "New Relic"
#   ],
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Software Engineer II, ITC',
#  'experience': '3-5 years',
#  'skills': ['Java',
#   'Spring Boot',
#   'ReactJS',
#   'HTML5',
#   'CSS3',
#   'JavaScript',
#   'Typescript',
#   'Micro service architecture',
#   'Domain driven design',
#   'RESTful Services',
#   'UI/UX principles',
#   'Continuous integration',
#   'Unit testing',
#   'Static analysis',
#   'Automated integration tests',
#   'Scrum and agile principles',
#   'AWS Services',
#   'GCE',
#   'Rackspace',
#   'Azure',
#   'NoSQL data stores (Cassandra, DynamoDB, MongoDB)',
#   'Relational data stores (MySQL, Oracle)',
#   'Splunk',
#   'SignalFx',
#   'New Relic'],
# ...

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack                           Links
# 0                React, Node.js, MongoDB  https://github.com/MohdRahim91
# 1               Angular,.NET, SQL Server  https://github.com/MohdRahim91
# 2      Vue.js, Ruby on Rails, PostgreSQL  https://github.com/MohdRahim91
# 3                  Python, Django, MySQL  https://github.com/MohdRahim91
# 4              Java, Spring Boot, Oracle  https://github.com/MohdRahim91
# 5             Flutter, Firebase, GraphQL  https://github.com/MohdRahim91
# 6                  WordPress, PHP, MySQL  https://github.com/MohdRahim91
# 7                    Magento, PHP, MySQL  https://github.com/MohdRahim91
# 8         React Native, Node.js, MongoDB  https://github.com/MohdRahim91
# 9                  iOS, Swift, Core Data  https://github.com/MohdRahim91
# 10       Android, Java, Room Persistence  https://github.com/MohdRahim91
# 11             Kotlin, Android, Firebase  https://github.com/MohdRahim91
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:02<00:00, 32.6MiB/s]

# %%
job = json_res
job['skills']
# Out:
# ['Java',
#  'Spring Boot',
#  'ReactJS',
#  'HTML5',
#  'CSS3',
#  'JavaScript',
#  'Typescript',
#  'Micro service architecture',
#  'Domain driven design',
#  'RESTful Services',
#  'UI/UX principles',
#  'Continuous integration',
#  'Unit testing',
#  'Static analysis',
#  'Automated integration tests',
#  'Scrum and agile principles',
#  'AWS Services',
#  'GCE',
#  'Rackspace',
#  'Azure',
#  'NoSQL data stores (Cassandra, DynamoDB, MongoDB)',
#  'Relational data stores (MySQL, Oracle)',
#  'Splunk',
#  'SignalFx',
#  'New Relic']

# %%
links= collection.query(query_texts=job["skills"], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
#  [{'links': 'https://github.com/MohdRahim91'},
#   {'links': 'https://github.com/MohdRahim91'}],
# ...

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Mohammed Rahim, a business development executive at Ryhorn. Ryhorn is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools.
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability,
        process optimization, cost reduction, and heightened overall efficiency.
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of Ryhorn
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Ryhorn's portfolio: {link_list}
        Remember you are Mohan, BDE at Ryhorn.
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Software Development Services for Nike's Digital Transformation
#
# Dear Hiring Manager,
#
# I came across the job description for a Software Engineer II, ITC at Nike, and I'm excited to introduce Ryhorn, an AI & Software Consulting company that can help you achieve your digital transformation goals. Our team of experts has extensive experience in developing high-throughput, low-latency, fault-tolerant systems, and we're confident that we can contribute to the success of Nike's supply chain platform.
#
# At Ryhorn, we specialize in designing, developing, and deploying scalable digital asset management systems and services. Our expertise in Java, Spring Boot, ReactJS, and Microservices architecture aligns perfectly with the requirements of the job description. We're also well-versed in UI/UX principles, Continuous Integration, Unit Testing, and Automated Integration Tests, ensuring that our solutions meet the highest standards of quality and reliability.
#
# ...
